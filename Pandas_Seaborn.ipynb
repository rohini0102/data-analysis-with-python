# %%
import pandas as pd

# %%
dia=pd.read_csv("/content/hi.csv")
dia
# Out:
#     Unnamed: 0   Names Initials  SEM1  SEM2  SEM3 Grade  Placed   average
# 0            0     Joe        K   9.8  10.0   9.9    A+       1  9.900000
# 1            1  Rajesh        M   8.9   9.1   9.3     A       1  9.100000
# 2            2  Kissan        V   9.9   9.8  10.0     A       0  9.900000
# 3            3    Mary        N   7.7   8.0   NaN     B       0       NaN
# 4            4    Jeen        K   9.8   9.1   9.9    A+       1  9.600000
# 5            5     Raj        M   8.9   9.1   9.3     A       1  9.100000
# 6            6  Hassan        V   9.9   9.0   9.2     A       1  9.366667
# 7            7    Mari        N   7.7   8.0   7.1     B       1  7.600000
# 8            8    Jess        K   NaN   9.1   9.9    A+       1       NaN
# 9            9  Rajini        M   NaN   9.1   9.3     A       0       NaN
# 10          10   Kiran        V   NaN   9.3   9.2     A       0       NaN
# 11          11    Maya        N   7.7   8.0   7.1     B       0  7.600000
# ...

# %%
import seaborn as sns

# %%
p1=sns.lineplot(x='Names',y='SEM1',data=dia)

# %%
sns.relplot(data=dia,x='Names',y='SEM1',col='Placed')
#col=graphs ARE SEPERATED BASED ON THIS COLUMN

# %%
diab=pd.read_excel("/content/diabets.exel.xlsx")
diab
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
diab['index']=range(1,769)
diab
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class  index
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive      1
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative      2
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive      3
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative      4
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive      5
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...    ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative    764
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative    765
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative    766
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive    767
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative    768
#
# [768 rows x 10 columns]

# %%
#create a relational plot using age= y axis ,index = x axis seperated by class
sns.relplot(data=diab,x='index',y='age',col='class')

# %%
tips=sns.load_dataset("tips")#tips is one of the dataset in seaborn
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#showing the difference by diffenting colrs -queue
sns.relplot(data=tips,x='total_bill',y='tip',hue='smoker')

# %%
sns.relplot(data=tips,x='total_bill',y='tip',hue='sex')

# %%
#additional feature andded to differentiate i.e., style for time
sns.relplot(data=tips,x='total_bill',y='tip',hue='smoker',style='time',palette='dark')

# %%
sns.relplot(data=tips,x='total_bill',y='tip',hue='size')

# %%
dj=sns.load_dataset("dowjones")#it is a dataset
print(dj)
# Out:
#           Date   Price
# 0   1914-12-01   55.00
# 1   1915-01-01   56.55
# 2   1915-02-01   56.00
# 3   1915-03-01   58.30
# 4   1915-04-01   66.45
# ..         ...     ...
# 644 1968-08-01  883.72
# 645 1968-09-01  922.80
# 646 1968-10-01  955.47
# 647 1968-11-01  964.12
# 648 1968-12-01  965.39
#
# [649 rows x 2 columns]

# %%
sns.relplot(data=dj,x="Date",y="Price",kind="line")

# %%
fm=sns.load_dataset("fmri")
print(fm)
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.relplot(data=fm,x='timepoint',y='signal',kind='line')#default:scatter

# %%
sns.relplot(data=fm,x='timepoint',y='signal')

# %%
sns.catplot(data=fm,x='timepoint',y='signal')

# %%
sns.catplot(data=fm,x='timepoint',y='signal',kind='violin')

# %%
sns.catplot(data=tips,x='total_bill',y='tip',kind='violin')

# %%
sns.catplot(data=tips,x='total_bill',y='tip',kind='violin',hue='smoker')

# %%
sns.catplot(data=tips,y='total_bill',x='time',kind='violin')

# %%
sns.catplot(data=tips,y='total_bill',x='time',kind='box',hue='smoker')

# %%
sns.catplot(data=tips,y='total_bill',x='time',kind='violin',hue='smoker')

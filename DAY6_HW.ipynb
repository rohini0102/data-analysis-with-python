# %%
import pandas as pd

# %%
import seaborn as sns

# %%
df=pd.read_csv("/content/data.csv")
df
# Out:
#        stn_code       sampling_date           state    location agency  \
# 0         150.0  February - M021990  Andhra Pradesh   Hyderabad    NaN
# 1         151.0  February - M021990  Andhra Pradesh   Hyderabad    NaN
# 2         152.0  February - M021990  Andhra Pradesh   Hyderabad    NaN
# 3         150.0     March - M031990  Andhra Pradesh   Hyderabad    NaN
# 4         151.0     March - M031990  Andhra Pradesh   Hyderabad    NaN
# ...         ...                 ...             ...         ...    ...
# 49000       NaN            23-03-05      Chandigarh  Chandigarh    NaN
# 49001       NaN            25-03-05      Chandigarh  Chandigarh    NaN
# 49002       NaN            28-03-05      Chandigarh  Chandigarh    NaN
# 49003       NaN            30-03-05      Chandigarh  Chandigarh    NaN
# 49004       NaN            4/1/2005      Chandigarh  Chandigarh    NaN
#
#                                      type   so2   no2   rspm    spm  \
# ...

# %%
state='Andhra Pradesh'
location='Eluru'
p1=sns.lineplot(x='location',y='no2',data=df)

# %%
sns.relplot(data=df,x="location",y="no2",hue="location",style="stn_code")
